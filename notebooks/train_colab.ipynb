# %% [markdown]
# # KL Grade Classification - Colab GPU Training
#
# 실행 전에 `런타임 > 런타임 유형 변경 > GPU`로 설정하세요.

# %%
# !nvidia-smi
# Out:
# Sat Jul 18 10:55:12 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   45C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# ## 1. Google Drive 마운트
# `KneeXrayData.zip`을 미리 자신의 Google Drive(예: `MyDrive/KneeXrayData.zip`)에 업로드해두세요.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## 2. 저장소 클론

# %%
# !git clone https://github.com/knh8412863/knee-kl-grade-classification.git
# %cd knee-kl-grade-classification
# Out:
# Cloning into 'knee-kl-grade-classification'...
# remote: Enumerating objects: 86, done.
# remote: Counting objects: 100% (86/86), done.
# remote: Compressing objects: 100% (50/50), done.
# remote: Total 86 (delta 38), reused 82 (delta 34), pack-reused 0 (from 0)
# Receiving objects: 100% (86/86), 469.28 KiB | 2.42 MiB/s, done.
# Resolving deltas: 100% (38/38), done.
# /content/knee-kl-grade-classification/knee-kl-grade-classification

# %% [markdown]
# ## 3. 데이터 압축 해제
# Drive에서 바로 읽으면 느리므로 Colab 로컬 디스크(`data/raw`)로 압축을 풉니다.

# %%
# !mkdir -p data/raw
# !unzip -q /content/drive/MyDrive/KneeXrayData.zip -d data/raw/

# %% [markdown]
# ## 4. 패키지 설치

# %%
# !pip install -q -r requirements.txt

# %% [markdown]
# ## 5. 학습 실행 (GPU)
# `config/default.yaml`은 로컬과 동일한 `data/raw/...` 상대 경로를 쓰므로 수정 없이 그대로 사용합니다.

# %%
# !python src/train.py --config config/default.yaml
# Out:
# epoch 1/25 train_loss=1.4363 val_accuracy=0.3995 val_kappa=0.6274 lr=0.000100
#   saved new best checkpoint to checkpoints/best.pth (kappa=0.6274)
# epoch 2/25 train_loss=0.7226 val_accuracy=0.4661 val_kappa=0.7020 lr=0.000100
#   saved new best checkpoint to checkpoints/best.pth (kappa=0.7020)
# epoch 3/25 train_loss=0.5659 val_accuracy=0.4831 val_kappa=0.7207 lr=0.000098
#   saved new best checkpoint to checkpoints/best.pth (kappa=0.7207)
# epoch 4/25 train_loss=0.4887 val_accuracy=0.5448 val_kappa=0.7530 lr=0.000096
#   saved new best checkpoint to checkpoints/best.pth (kappa=0.7530)
# epoch 5/25 train_loss=0.4372 val_accuracy=0.5533 val_kappa=0.7776 lr=0.000094
#   saved new best checkpoint to checkpoints/best.pth (kappa=0.7776)
# epoch 6/25 train_loss=0.3955 val_accuracy=0.5496 val_kappa=0.7631 lr=0.000090
# epoch 7/25 train_loss=0.3697 val_accuracy=0.5654 val_kappa=0.7568 lr=0.000086
# epoch 8/25 train_loss=0.3319 val_accuracy=0.5908 val_kappa=0.7743 lr=0.000082
# epoch 9/25 train_loss=0.2792 val_accuracy=0.5835 val_kappa=0.7807 lr=0.000077
#   saved new best checkpoint to checkpoints/best.pth (kappa=0.7807)
# epoch 10/25 train_loss=0.2731 val_accuracy=0.5763 val_kappa=0.7635 lr=0.000071
# epoch 11/25 train_loss=0.2605 val_accuracy=0.6211 val_kappa=0.7819 lr=0.000065
#   saved new best checkpoint to checkpoints/best.pth (kappa=0.7819)
# epoch 12/25 train_loss=0.2291 val_accuracy=0.6090 val_kappa=0.7733 lr=0.000059
# epoch 13/25 train_loss=0.1999 val_accuracy=0.5944 val_kappa=0.7741 lr=0.000053
# epoch 14/25 train_loss=0.2004 val_accuracy=0.5860 val_kappa=0.7601 lr=0.000047
# epoch 15/25 train_loss=0.1722 val_accuracy=0.6162 val_kappa=0.7648 lr=0.000041
# epoch 16/25 train_loss=0.1590 val_accuracy=0.6199 val_kappa=0.7661 lr=0.000035
# epoch 17/25 train_loss=0.1509 val_accuracy=0.6283 val_kappa=0.7709 lr=0.000029
# epoch 18/25 train_loss=0.1257 val_accuracy=0.6162 val_kappa=0.7744 lr=0.000023
# epoch 19/25 train_loss=0.1141 val_accuracy=0.6150 val_kappa=0.7678 lr=0.000018
# epoch 20/25 train_loss=0.1118 val_accuracy=0.6053 val_kappa=0.7590 lr=0.000014
# epoch 21/25 train_loss=0.1030 val_accuracy=0.6199 val_kappa=0.7711 lr=0.000010
# epoch 22/25 train_loss=0.0972 val_accuracy=0.6199 val_kappa=0.7706 lr=0.000006
# epoch 23/25 train_loss=0.0994 val_accuracy=0.6199 val_kappa=0.7749 lr=0.000004
# epoch 24/25 train_loss=0.0942 val_accuracy=0.6174 val_kappa=0.7706 lr=0.000002
# epoch 25/25 train_loss=0.0993 val_accuracy=0.6162 val_kappa=0.7713 lr=0.000000

# %% [markdown]
# ## 6. 체크포인트를 Drive에 백업
# Colab 런타임이 종료되면 로컬 파일이 사라지므로, 학습이 끝나면 체크포인트를 Drive로 복사해두세요.

# %%
# !mkdir -p /content/drive/MyDrive/knee_kl_checkpoints
# !cp checkpoints/best.pth /content/drive/MyDrive/knee_kl_checkpoints/
